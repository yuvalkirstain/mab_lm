# %%
import pandas as pd

# %%
# df = pd.read_json("../raw_data/wikitext-103/wiki.valid.tokens.title_map.json", orient="index")
df = pd.read_json("../raw_data/wikitext-103/wiki.train.tokens.title_map.wiki_info", orient="index")
df.head(3)
# Out:
#                                            start_line_idx  end_line_idx  \
# Valkyria Chronicles III                                 0            50
# Tower Building of the Little Rock Arsenal              51           132
# Cicely Mary Barker                                    133           270
#
#                                                                                     WARNINGS  \
# Valkyria Chronicles III                    {'extracts': {'warnings': 'HTML may be malform...
# Tower Building of the Little Rock Arsenal  {'extracts': {'warnings': 'HTML may be malform...
# Cicely Mary Barker                         {'extracts': {'warnings': 'HTML may be malform...
#
#                                            redirected      pageid  \
# Valkyria Chronicles III                           NaN  28842499.0
# Tower Building of the Little Rock Arsenal         NaN   1216380.0
# Cicely Mary Barker                                NaN     65100.0
#
# ...

# %%
df.what.value_counts()[:30]
# Out:
# human                              5048
# television series episode          1674
# road                               1124
# taxon                              1004
# single                              873
# video game                          825
# film                                659
# album                               635
# battle                              412
# song                                360
# ship                                296
# fictional human                     269
# literary work                       264
# written work                        217
# cyclone                             197
# ship class                          192
# studio album                        186
# The Boat Race                       160
# fossil taxon                        147
# musical group                       145
# tropical storm                      134
# aspect of history                   134
# Wikimedia disambiguation page       131
# ...

# %%
df_cats = df[['query_title', 'title', 'categories']].explode('categories').reset_index()
df_cats.categories.value_counts()[:30]
# Out:
# Category:Living people                                  1638
# Category:American films                                  558
# Category:English-language films                          531
# Category:Windows games                                   345
# Category:Video games developed in Japan                  340
# Category:Video games developed in the United States      319
# Category:Single-player video games                       316
# Category:IUCN Red List least concern species             270
# Category:Multiplayer and single-player video games       248
# Category:Fungi of North America                          204
# Category:Pop ballads                                     180
# Category:English Football League players                 164
# Category:The Boat Race                                   160
# Category:State highways in New York (state)              158
# Category:Fungi of Asia                                   157
# ...

# %%
df_labels = df[['query_title', 'title', 'labels']]
df_labels["labels_list"] = df_labels.labels.apply(lambda dic: [v for k, v in dic.items()] if type(dic) == dict else [])
df_labels = df_labels.explode('labels_list').reset_index()
df_labels.labels_list.value_counts()[:30]
# Out:
# /home/mega/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# instance of                                         25606
# Freebase ID                                         23950
# Commons category                                    13131
# image                                               13060
# United States of America                             8723
# country                                              6869
# publication date                                     6399
# genre                                                5803
# sex or gender                                        5574
# English                                              5402
# ...
